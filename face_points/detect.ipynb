# %%
from detection import detect


preds_2 = detect("checkpoints/facepoints_model.pt", r"./data/00_test_img_input/test/images", batch_size=1)
# Out:
# [tensor([2.6200], dtype=torch.float64), tensor([2.6200], dtype=torch.float64)]
# torch.Size([1, 28])
# [tensor([0.9400], dtype=torch.float64), tensor([0.9400], dtype=torch.float64)]
# torch.Size([1, 28])
# [tensor([1.6600], dtype=torch.float64), tensor([1.6600], dtype=torch.float64)]
# torch.Size([1, 28])
# [tensor([1.2400], dtype=torch.float64), tensor([1.2400], dtype=torch.float64)]
# torch.Size([1, 28])
# [tensor([1.8900], dtype=torch.float64), tensor([1.8900], dtype=torch.float64)]
# torch.Size([1, 28])
# [tensor([1.7700], dtype=torch.float64), tensor([1.7700], dtype=torch.float64)]
# torch.Size([1, 28])
# [tensor([2.0400], dtype=torch.float64), tensor([2.0400], dtype=torch.float64)]
# torch.Size([1, 28])
# [tensor([4.7100], dtype=torch.float64), tensor([4.7100], dtype=torch.float64)]
# torch.Size([1, 28])
# [tensor([0.8100], dtype=torch.float64), tensor([0.8100], dtype=torch.float64)]
# torch.Size([1, 28])
# ...

# %%
import detection
from importlib import reload

reload(detection)
# Out:
# <module 'detection' from '/home/hakob/KissMe/MIPT/CV/CV-Yandex/Точки лица/detection.py'>

# %%
preds["05670.jpg"]
# Out:
# array([ 8.168726, 13.025721, 17.856726, 10.477676, 28.965876,  9.580497,
#        40.367805, 10.177562, 11.092877, 17.171576, 15.013597, 16.341694,
#        18.419313, 16.284817, 30.207996, 15.268614, 34.089928, 14.604839,
#        38.000443, 14.771527, 23.6193  , 23.71259 , 17.262842, 34.12043 ,
#        24.998968, 33.705593, 33.24492 , 32.850758], dtype=float32)

# %%
preds_2["05670.jpg"]
# Out:
# array([ 8.168726, 13.025721, 17.856726, 10.477676, 28.965876,  9.580497,
#        40.367805, 10.177562, 11.092877, 17.171576, 15.013597, 16.341694,
#        18.419313, 16.284817, 30.207996, 15.268614, 34.089928, 14.604839,
#        38.000443, 14.771527, 23.6193  , 23.71259 , 17.262842, 34.12043 ,
#        24.998968, 33.705593, 33.24492 , 32.850758], dtype=float32)
